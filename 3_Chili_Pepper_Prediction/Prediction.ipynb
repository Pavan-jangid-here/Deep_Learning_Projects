# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Rescaling, Flatten
from tensorflow.keras.models import Sequential
import os

# %%
train_directory = "train"

image_height = 100
image_width = 100
batch_size = 32


train_ds = image_dataset_from_directory(
    train_directory,
    validation_split = 0.2,
    subset = "training",
    seed = 123,
    image_size = (image_height, image_width),
    batch_size = batch_size
)

validation_ds = image_dataset_from_directory(
    train_directory,
    validation_split = 0.2,
    subset = "validation",
    seed = 123,
    image_size = (image_height, image_width),
    batch_size = batch_size
)
# Out:
# Found 200 files belonging to 2 classes.
# Using 160 files for training.
# Found 200 files belonging to 2 classes.
# Using 40 files for validation.

# %%
train_ds.class_names
# Out:
# ['healthy', 'unhealthy']

# %%
model = Sequential()

model.add(Rescaling(1.0 / 255, input_shape = (image_height, image_width, 3)))

model.add(Conv2D(64, 3, activation = "relu"))

model.add(MaxPooling2D())

model.add(Conv2D(128, 3, activation = "relu"))

model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(128, activation = "relu"))

model.add(Dense(len(train_ds.class_names), activation = "softmax"))

model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

model.fit(train_ds, validation_data = validation_ds, epochs = 16)
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.5750 - loss: 1.4638 - val_accuracy: 0.7750 - val_loss: 0.6692
# Epoch 2/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - accuracy: 0.6062 - loss: 0.6664 - val_accuracy: 0.8250 - val_loss: 0.6144
# Epoch 3/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 0.7750 - loss: 0.5414 - val_accuracy: 0.8000 - val_loss: 0.5205
# Epoch 4/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 344ms/step - accuracy: 0.8687 - loss: 0.3718 - val_accuracy: 0.8000 - val_loss: 0.6438
# Epoch 5/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 349ms/step - accuracy: 0.8625 - loss: 0.2802 - val_accuracy: 0.8250 - val_loss: 0.4775
# Epoch 6/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 355ms/step - accuracy: 0.9563 - loss: 0.1413 - val_accuracy: 0.8000 - val_loss: 0.4407
# Epoch 7/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - accuracy: 0.9750 - loss: 0.0744 - val_accuracy: 0.8500 - val_loss: 0.4249
# Epoch 8/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 353ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 0.8500 - val_loss: 0.4414
# Epoch 9/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9000 - val_loss: 0.5280
# Epoch 10/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 354ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8750 - val_loss: 0.5784
# Epoch 11/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9000 - val_loss: 0.6089
# Epoch 12/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 340ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9000 - val_loss: 0.5594
# Epoch 13/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 336ms/step - accuracy: 1.0000 - loss: 8.8388e-04 - val_accuracy: 0.8750 - val_loss: 0.5755
# Epoch 14/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 1.0000 - loss: 6.3224e-04 - val_accuracy: 0.8750 - val_loss: 0.6139
# Epoch 15/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 348ms/step - accuracy: 1.0000 - loss: 2.8386e-04 - val_accuracy: 0.8750 - val_loss: 0.6684
# Epoch 16/16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 337ms/step - accuracy: 1.0000 - loss: 1.7824e-04 - val_accuracy: 0.8500 - val_loss: 0.7263

# %%
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img("67.jpg", target_size = (100, 100))

img_array = image.img_to_array(img)

img_array = img_array/255.0

img_array = np.expand_dims(img_array, axis = 0)

model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 902ms/step
# array([[0.15553741, 0.84446263]], dtype=float32)
